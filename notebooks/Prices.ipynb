# %%
# %load_ext autoreload

# %autoreload 2
import sys
# sys.path.append('../mockportfolio/')
sys.path.append('../')
data_path = '../data/'
from mockportfolio import Holdings, Prices
holdings = Holdings(data_path)
prices = Prices(data_path)

# %%
import numpy as np
from empyrical import *
price_data = prices.get_prices()

tick_price = price_data[price_data.Tick == 'TNE']

# manual calc of returns
#tick_price['Returns'] = (tick_price.Close - tick_price.Close.shift(1)) / tick_price.Close.shift(1)

tick_price['Returns'] = simple_returns(tick_price.Close)
tick_price['CumReturns'] = cum_returns(tick_price.Returns)
display(tick_price)
print('returns', "{0:.0%}".format(annual_return(tick_price.Returns)))
print('drawdown', "{0:.0%}".format(max_drawdown(tick_price.Returns)))
print('sharpe', "{0:.0%}".format(sharpe_ratio(tick_price.Returns)))
print('volatility',  "{0:.0%}".format(annual_volatility(tick_price.Returns)))
# Out:
# d:\utils\anaconda3\envs\mockportfolio\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# d:\utils\anaconda3\envs\mockportfolio\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
#              Date  Open  High    Low  Close  Adj Close     Volume Tick  \
# ...
